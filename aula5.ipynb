# %% [markdown]
#  *Bases de dados*

# %%
import pandas as pd #Importa tabelas
import numpy as np

# %%
nomes = pd.DataFrame({'Nome':['Renato', 'Gabriel', 'Luiza', 'Camille'],
              'Numero':[1,2,3,4]}) #Para criar tabelas inserindo manualmente
nomes
# Out:
#       Nome  Numero
# 0   Renato       1
# 1  Gabriel       2
# 2    Luiza       3
# 3  Camille       4

# %%
nomes['Nome']
# Out:
# 0     Renato
# 1    Gabriel
# 2      Luiza
# 3    Camille
# Name: Nome, dtype: object

# %%
nomes['Numero']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: Numero, dtype: int64

# %%
compras = pd.read_csv('https://raw.githubusercontent.com/BMClab/BasesComputacionais/master/dados/compras.csv') #Para imporar links
compras
# Out:
#    Produto Fabricante  Qtd Medida  Preço Supermercado        Data
# 0     Suco   ValeSuco    1      l   3.00     Arpoador  12/05/2011
# 1     Suco      Flash    1      l   4.50     Arpoador  18/05/2011
# 2   Tomate         -     1     kg   3.50        Noite  14/05/2011
# 3    Arroz   Tio José    4     kg   8.64        Noite  14/05/2011
# 4    Arroz  Sem Broto    5     kg   9.99     Arpoador  10/06/2011
# 5    Arroz      Da TV    1     kg   1.99        Noite  14/06/2011
# 6   Feijão  Sem Broto    1     kg   4.00     Arpoador  12/05/2011
# 7   Tomate         -     1     kg   2.99        Noite  16/05/2011
# 8      Ovo   A Granja   12      u   3.19     Arpoador  12/06/2011
# 9      Ovo    Caseiro    6      u   1.45        Noite  14/05/2011
# 10    Suco      Flash    1      l   3.99        Noite  21/07/2011

# %%
info = pd.read_csv('https://raw.githubusercontent.com/BMClab/BasesComputacionais/master/dados/BDSinfo.csv', sep='\t') # sep serve para separar
info
# Out:
#          Trial  Subject  Vision Surface        Age AgeGroup Gender  Height  \
# 0     BDS00001        1    Open    Firm  33.000000    Young      F   157.5
# 1     BDS00002        1    Open    Firm  33.000000    Young      F   157.5
# 2     BDS00003        1    Open    Firm  33.000000    Young      F   157.5
# 3     BDS00004        1  Closed    Firm  33.000000    Young      F   157.5
# 4     BDS00005        1  Closed    Firm  33.000000    Young      F   157.5
# ...        ...      ...     ...     ...        ...      ...    ...     ...
# 1925  BDS01952      163    Open    Firm  25.416667    Young      M   172.0
# 1926  BDS01953      163    Open    Firm  25.416667    Young      M   172.0
# 1927  BDS01954      163  Closed    Foam  25.416667    Young      M   172.0
# 1928  BDS01955      163  Closed    Foam  25.416667    Young      M   172.0
# 1929  BDS01956      163  Closed    Foam  25.416667    Young      M   172.0
#
# ...

# %%
info['Age'] #Para informar o que deseja
# Out:
# 0       33.000000
# 1       33.000000
# 2       33.000000
# 3       33.000000
# 4       33.000000
#           ...
# 1925    25.416667
# 1926    25.416667
# 1927    25.416667
# 1928    25.416667
# 1929    25.416667
# Name: Age, Length: 1930, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.grid()
plt.plot(info['Height'],info['Weight'], marker = 'o', color = 'red', linestyle = '')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
info.query('Gender == "F" and Age == 33 and Vision == "Open"') #Serve para filtrar o que deseja
# Out:
#       Trial  Subject Vision Surface   Age AgeGroup Gender  Height  Weight  \
# 0  BDS00001        1   Open    Firm  33.0    Young      F   157.5    54.2
# 1  BDS00002        1   Open    Firm  33.0    Young      F   157.5    54.2
# 2  BDS00003        1   Open    Firm  33.0    Young      F   157.5    54.2
# 6  BDS00007        1   Open    Foam  33.0    Young      F   157.5    54.2
# 7  BDS00008        1   Open    Foam  33.0    Young      F   157.5    54.2
# 8  BDS00009        1   Open    Foam  33.0    Young      F   157.5    54.2
#
#          BMI  ...  Best_7 Best_8 Best_9  Best_10 Best_11 Best_12 Best_13  \
# 0  21.849332  ...       2      2      2        2       2       2       2
# 1  21.849332  ...       2      2      2        2       2       2       2
# 2  21.849332  ...       2      2      2        2       2       2       2
# 6  21.849332  ...       2      2      2        2       2       2       2
# 7  21.849332  ...       2      2      2        2       2       2       2
# ...

# %%
info.query('AgeGroup == "Old" and Gender == "M" and Surface == "Foam"')
# Out:
#          Trial  Subject  Vision Surface        Age AgeGroup Gender  Height  \
# 39    BDS00040        4    Open    Foam  61.750000      Old      M   164.0
# 40    BDS00041        4    Open    Foam  61.750000      Old      M   164.0
# 41    BDS00042        4    Open    Foam  61.750000      Old      M   164.0
# 42    BDS00043        4  Closed    Foam  61.750000      Old      M   164.0
# 43    BDS00044        4  Closed    Foam  61.750000      Old      M   164.0
# ...        ...      ...     ...     ...        ...      ...    ...     ...
# 1817  BDS01844      154  Closed    Foam  71.833333      Old      M   172.8
# 1818  BDS01845      154  Closed    Foam  71.833333      Old      M   172.8
# 1819  BDS01846      154    Open    Foam  71.833333      Old      M   172.8
# 1820  BDS01847      154    Open    Foam  71.833333      Old      M   172.8
# 1821  BDS01848      154    Open    Foam  71.833333      Old      M   172.8
#
# ...

# %%
info.query('Height > 170 or Weight > 70')
# Out:
#          Trial  Subject  Vision Surface        Age AgeGroup Gender  Height  \
# 60    BDS00061        6    Open    Foam  49.333333    Young      M   163.5
# 61    BDS00062        6    Open    Foam  49.333333    Young      M   163.5
# 62    BDS00063        6    Open    Foam  49.333333    Young      M   163.5
# 63    BDS00064        6  Closed    Foam  49.333333    Young      M   163.5
# 64    BDS00065        6  Closed    Foam  49.333333    Young      M   163.5
# ...        ...      ...     ...     ...        ...      ...    ...     ...
# 1925  BDS01952      163    Open    Firm  25.416667    Young      M   172.0
# 1926  BDS01953      163    Open    Firm  25.416667    Young      M   172.0
# 1927  BDS01954      163  Closed    Foam  25.416667    Young      M   172.0
# 1928  BDS01955      163  Closed    Foam  25.416667    Young      M   172.0
# 1929  BDS01956      163  Closed    Foam  25.416667    Young      M   172.0
#
# ...

# %%
info.sort_values(['Age']) #Serve para ordenar crescente
# Out:
#          Trial  Subject  Vision Surface        Age AgeGroup Gender  Height  \
# 56    BDS00057        5    Open    Firm  18.333333    Young      F   162.0
# 55    BDS00056        5    Open    Firm  18.333333    Young      F   162.0
# 54    BDS00055        5    Open    Firm  18.333333    Young      F   162.0
# 53    BDS00054        5  Closed    Foam  18.333333    Young      F   162.0
# 52    BDS00053        5  Closed    Foam  18.333333    Young      F   162.0
# ...        ...      ...     ...     ...        ...      ...    ...     ...
# 1225  BDS01241      104  Closed    Firm  85.833333      Old      F   145.7
# 1224  BDS01240      104  Closed    Firm  85.833333      Old      F   145.7
# 1223  BDS01239      104  Closed    Foam  85.833333      Old      F   145.7
# 1228  BDS01244      104    Open    Foam  85.833333      Old      F   145.7
# 1222  BDS01238      104  Closed    Foam  85.833333      Old      F   145.7
#
# ...

# %%
info.sort_values(['Age'], ascending = False) #Serve para ordenar decrescente
# Out:
#          Trial  Subject  Vision Surface        Age AgeGroup Gender  Height  \
# 1224  BDS01240      104  Closed    Firm  85.833333      Old      F   145.7
# 1228  BDS01244      104    Open    Foam  85.833333      Old      F   145.7
# 1225  BDS01241      104  Closed    Firm  85.833333      Old      F   145.7
# 1232  BDS01248      104    Open    Firm  85.833333      Old      F   145.7
# 1231  BDS01247      104    Open    Firm  85.833333      Old      F   145.7
# ...        ...      ...     ...     ...        ...      ...    ...     ...
# 51    BDS00052        5  Closed    Foam  18.333333    Young      F   162.0
# 58    BDS00059        5    Open    Foam  18.333333    Young      F   162.0
# 59    BDS00060        5    Open    Foam  18.333333    Young      F   162.0
# 50    BDS00051        5  Closed    Firm  18.333333    Young      F   162.0
# 48    BDS00049        5  Closed    Firm  18.333333    Young      F   162.0
#
# ...

# %%
info.sort_values(['BMI'], ascending = False)
# Out:
#          Trial  Subject  Vision Surface        Age AgeGroup Gender  Height  \
# 937   BDS00947       79    Open    Foam  72.250000      Old      F   148.5
# 930   BDS00940       79  Closed    Firm  72.250000      Old      F   148.5
# 932   BDS00942       79  Closed    Firm  72.250000      Old      F   148.5
# 933   BDS00943       79    Open    Firm  72.250000      Old      F   148.5
# 934   BDS00944       79    Open    Firm  72.250000      Old      F   148.5
# ...        ...      ...     ...     ...        ...      ...    ...     ...
# 1627  BDS01654      138  Closed    Firm  24.166667    Young      M   180.4
# 1628  BDS01655      138  Closed    Firm  24.166667    Young      M   180.4
# 1629  BDS01656      138  Closed    Firm  24.166667    Young      M   180.4
# 1618  BDS01645      138    Open    Firm  24.166667    Young      M   180.4
# 1619  BDS01646      138    Open    Firm  24.166667    Young      M   180.4
#
# ...

# %%
info.sort_values(['Gender' , 'Age'])
# Out:
#         Trial  Subject  Vision Surface        Age AgeGroup Gender  Height  \
# 48   BDS00049        5  Closed    Firm  18.333333    Young      F   162.0
# 49   BDS00050        5  Closed    Firm  18.333333    Young      F   162.0
# 50   BDS00051        5  Closed    Firm  18.333333    Young      F   162.0
# 51   BDS00052        5  Closed    Foam  18.333333    Young      F   162.0
# 52   BDS00053        5  Closed    Foam  18.333333    Young      F   162.0
# ..        ...      ...     ...     ...        ...      ...    ...     ...
# 982  BDS00992       83    Open    Foam  80.083333      Old      M   158.8
# 983  BDS00993       83    Open    Foam  80.083333      Old      M   158.8
# 984  BDS00994       83    Open    Firm  80.083333      Old      M   158.8
# 985  BDS00995       83    Open    Firm  80.083333      Old      M   158.8
# 986  BDS00996       83    Open    Firm  80.083333      Old      M   158.8
#
#      Weight        BMI  ...  Best_7 Best_8 Best_9  Best_10 Best_11 Best_12  \
# ...

# %%
compras['Data'] = pd.to_datetime(compras['Data'], format = '%d/%m/%Y') #Para trabalhar com datas
compras
# Out:
#    Produto Fabricante  Qtd Medida  Preço Supermercado       Data
# 0     Suco   ValeSuco    1      l   3.00     Arpoador 2011-05-12
# 1     Suco      Flash    1      l   4.50     Arpoador 2011-05-18
# 2   Tomate         -     1     kg   3.50        Noite 2011-05-14
# 3    Arroz   Tio José    4     kg   8.64        Noite 2011-05-14
# 4    Arroz  Sem Broto    5     kg   9.99     Arpoador 2011-06-10
# 5    Arroz      Da TV    1     kg   1.99        Noite 2011-06-14
# 6   Feijão  Sem Broto    1     kg   4.00     Arpoador 2011-05-12
# 7   Tomate         -     1     kg   2.99        Noite 2011-05-16
# 8      Ovo   A Granja   12      u   3.19     Arpoador 2011-06-12
# 9      Ovo    Caseiro    6      u   1.45        Noite 2011-05-14
# 10    Suco      Flash    1      l   3.99        Noite 2011-07-21

# %%
compras = compras.sort_values(['Data' , 'Preço'])
compras
# Out:
#    Produto Fabricante  Qtd Medida  Preço Supermercado       Data
# 0     Suco   ValeSuco    1      l   3.00     Arpoador 2011-05-12
# 6   Feijão  Sem Broto    1     kg   4.00     Arpoador 2011-05-12
# 9      Ovo    Caseiro    6      u   1.45        Noite 2011-05-14
# 2   Tomate         -     1     kg   3.50        Noite 2011-05-14
# 3    Arroz   Tio José    4     kg   8.64        Noite 2011-05-14
# 7   Tomate         -     1     kg   2.99        Noite 2011-05-16
# 1     Suco      Flash    1      l   4.50     Arpoador 2011-05-18
# 4    Arroz  Sem Broto    5     kg   9.99     Arpoador 2011-06-10
# 8      Ovo   A Granja   12      u   3.19     Arpoador 2011-06-12
# 5    Arroz      Da TV    1     kg   1.99        Noite 2011-06-14
# 10    Suco      Flash    1      l   3.99        Noite 2011-07-21

# %%
compras['Mês'] = compras['Data'].dt.month #Para escolher os meses
compras
# Out:
#    Produto Fabricante  Qtd Medida  Preço Supermercado       Data  Mês
# 0     Suco   ValeSuco    1      l   3.00     Arpoador 2011-05-12    5
# 6   Feijão  Sem Broto    1     kg   4.00     Arpoador 2011-05-12    5
# 9      Ovo    Caseiro    6      u   1.45        Noite 2011-05-14    5
# 2   Tomate         -     1     kg   3.50        Noite 2011-05-14    5
# 3    Arroz   Tio José    4     kg   8.64        Noite 2011-05-14    5
# 7   Tomate         -     1     kg   2.99        Noite 2011-05-16    5
# 1     Suco      Flash    1      l   4.50     Arpoador 2011-05-18    5
# 4    Arroz  Sem Broto    5     kg   9.99     Arpoador 2011-06-10    6
# 8      Ovo   A Granja   12      u   3.19     Arpoador 2011-06-12    6
# 5    Arroz      Da TV    1     kg   1.99        Noite 2011-06-14    6
# 10    Suco      Flash    1      l   3.99        Noite 2011-07-21    7

# %%
 compras['Ano'] = compras ['Data'].dt.year # Para adicionar ano
# Out:
#    Produto Fabricante  Qtd Medida  Preço Supermercado       Data  Mês   Ano
# 0     Suco   ValeSuco    1      l   3.00     Arpoador 2011-05-12    5  2011
# 6   Feijão  Sem Broto    1     kg   4.00     Arpoador 2011-05-12    5  2011
# 9      Ovo    Caseiro    6      u   1.45        Noite 2011-05-14    5  2011
# 2   Tomate         -     1     kg   3.50        Noite 2011-05-14    5  2011
# 3    Arroz   Tio José    4     kg   8.64        Noite 2011-05-14    5  2011
# 7   Tomate         -     1     kg   2.99        Noite 2011-05-16    5  2011
# 1     Suco      Flash    1      l   4.50     Arpoador 2011-05-18    5  2011
# 4    Arroz  Sem Broto    5     kg   9.99     Arpoador 2011-06-10    6  2011
# 8      Ovo   A Granja   12      u   3.19     Arpoador 2011-06-12    6  2011
# 5    Arroz      Da TV    1     kg   1.99        Noite 2011-06-14    6  2011
# 10    Suco      Flash    1      l   3.99        Noite 2011-07-21    7  2011

# %%
info['AgeGroup'].value_counts()
# Out:
# Young    1041
# Old       889
# Name: AgeGroup, dtype: int64

# %%
info['Gender'].value_counts()
# Out:
# F    1383
# M     547
# Name: Gender, dtype: int64

# %%
len(info.query('Age <= 33'))
# Out:
# 840

# %%
info.query('Age <= 33') ['Gender'].value_counts()
# Out:
# F    540
# M    300
# Name: Gender, dtype: int64

# %%
info.head(20) #Mostrar as x primeira linhas
# Out:
#        Trial  Subject  Vision Surface        Age AgeGroup Gender  Height  \
# 0   BDS00001        1    Open    Firm  33.000000    Young      F   157.5
# 1   BDS00002        1    Open    Firm  33.000000    Young      F   157.5
# 2   BDS00003        1    Open    Firm  33.000000    Young      F   157.5
# 3   BDS00004        1  Closed    Firm  33.000000    Young      F   157.5
# 4   BDS00005        1  Closed    Firm  33.000000    Young      F   157.5
# 5   BDS00006        1  Closed    Firm  33.000000    Young      F   157.5
# 6   BDS00007        1    Open    Foam  33.000000    Young      F   157.5
# 7   BDS00008        1    Open    Foam  33.000000    Young      F   157.5
# 8   BDS00009        1    Open    Foam  33.000000    Young      F   157.5
# 9   BDS00010        1  Closed    Foam  33.000000    Young      F   157.5
# 10  BDS00011        1  Closed    Foam  33.000000    Young      F   157.5
# 11  BDS00012        1  Closed    Foam  33.000000    Young      F   157.5
# ...

# %%
info.tail(25) #Para mostrar x ultimas linhas
# Out:
#          Trial  Subject  Vision Surface        Age AgeGroup Gender  Height  \
# 1905  BDS01932      161    Open    Foam  25.333333    Young      F   167.7
# 1906  BDS01933      162  Closed    Foam  24.083333    Young      M   183.5
# 1907  BDS01934      162  Closed    Foam  24.083333    Young      M   183.5
# 1908  BDS01935      162  Closed    Foam  24.083333    Young      M   183.5
# 1909  BDS01936      162  Closed    Firm  24.083333    Young      M   183.5
# 1910  BDS01937      162  Closed    Firm  24.083333    Young      M   183.5
# 1911  BDS01938      162  Closed    Firm  24.083333    Young      M   183.5
# 1912  BDS01939      162    Open    Firm  24.083333    Young      M   183.5
# 1913  BDS01940      162    Open    Firm  24.083333    Young      M   183.5
# 1914  BDS01941      162    Open    Firm  24.083333    Young      M   183.5
# 1915  BDS01942      162    Open    Foam  24.083333    Young      M   183.5
# ...

# %%
info.head(1)
# Out:
#       Trial  Subject Vision Surface   Age AgeGroup Gender  Height  Weight  \
# 0  BDS00001        1   Open    Firm  33.0    Young      F   157.5    54.2
#
#          BMI  ...  Best_7 Best_8 Best_9  Best_10 Best_11 Best_12 Best_13  \
# 0  21.849332  ...       2      2      2        2       2       2       2
#
#    Best_14 Best_T                     Date
# 0        1     25  2015-10-08 08:30:00.000
#
# [1 rows x 64 columns]

# %%
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1930 entries, 0 to 1929
# Data columns (total 64 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Trial              1930 non-null   object
#  1   Subject            1930 non-null   int64
#  2   Vision             1930 non-null   object
#  3   Surface            1930 non-null   object
#  4   Age                1930 non-null   float64
#  5   AgeGroup           1930 non-null   object
#  6   Gender             1930 non-null   object
#  7   Height             1930 non-null   float64
#  8   Weight             1930 non-null   float64
#  9   BMI                1930 non-null   float64
#  10  FootLen            1906 non-null   float64
#  11  Nationality        1930 non-null   object
#  12  SkinColor          1930 non-null   object
#  13  Ystudy             1930 non-null   int64
#  14  Footwear           1930 non-null   object
#  15  Illness            1930 non-null   object
# ...

# %%
compras.info() #Para ter informações da tabela
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 0 to 10
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Produto       11 non-null     object
#  1   Fabricante    11 non-null     object
#  2   Qtd           11 non-null     int64
#  3   Medida        11 non-null     object
#  4   Preço         11 non-null     float64
#  5   Supermercado  11 non-null     object
#  6   Data          11 non-null     datetime64[ns]
#  7   Mês           11 non-null     int64
#  8   Ano           11 non-null     int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 880.0+ bytes

# %%
info.groupby('Gender')['Height'].mean() #Serve para tirar média por grupos
# Out:
# Gender
# F    158.498482
# M    172.052834
# Name: Height, dtype: float64

# %%
info.groupby('Gender')['Weight'].mean()
# Out:
# Gender
# F    60.288395
# M    67.059232
# Name: Weight, dtype: float64

# %%
info.groupby('AgeGroup')['BMI'].mean()
# Out:
# AgeGroup
# Old      25.484218
# Young    22.193638
# Name: BMI, dtype: float64
